# %%
text="Hello"
print(text)
# Out:
# Hello

# %%
text.upper()
# Out:
# 'HELLO'

# %%
text.capitalize()
# Out:
# 'Hello'

# %%
text02="i love you"
text+text02
# Out:
# 'Helloi love you'

# %%
text+" "+text02
# Out:
# 'Hello i love you'

# %%
text*5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
text[0]
# Out:
# 'H'

# %%
text[2]
# Out:
# 'l'

# %%
x=(4<5)
print(x)
# Out:
# True

# %%
type(x)
# Out:
# bool

# %%
text03="日本が好き"
print(text03)
# Out:
# 日本が好き

# %%
type(None)
# Out:
# NoneType

# %%
value=print("abc")
print(value)
# Out:
# abc
# None

# %%
L=[4,6,8,9]
print(len(L))
# Out:
# 4

# %%
L.append(11)

# %%
L.sort
L
# Out:
# [4, 6, 8, 9, 11]

# %%
L +=[1, 17,20]
L
# Out:
# [4, 6, 8, 9, 11, 1, 17, 20]

# %%
L=[1,"two",3,24,[0,3,5]]
L
# Out:
# [1, 'two', 3, 24, [0, 3, 5]]

# %%
L=[1,"i love japan",2,3,[0,7,9]]
L
# Out:
# [1, 'i love japan', 2, 3, [0, 7, 9]]

# %%
k=[1]
k1="two"
k2=[4,5,7]
k.append(k1)
k.append(k2) 
k
# Out:
# [1, 'two', [4, 5, 7]]

# %%
L=[4,6,8,9,11]
L[0]
# Out:
# 4

# %%
L[3]
# Out:
# 9

# %%
L[4]
# Out:
# 11

# %%
L[:3]
# Out:
# [4, 6, 8]

# %%
L[::2]
# Out:
# [4, 8, 11]

# %%
L[0:len(L):2]
# Out:
# [4, 8, 11]

# %%
L[::-2]
# Out:
# [11, 8, 4]

# %%
L[-2:]
# Out:
# [9, 11]

# %%
T=(4,9,10)
print(T)
# Out:
# (4, 9, 10)

# %%
T=4,9,10
print(T)
# Out:
# (4, 9, 10)

# %%
len(T)
# Out:
# 3

# %%
T[1]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-1e05dc548a05> in <module>()
# ----> 1 T[1]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
T.append(12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-e9e4bc125115> in <module>()
# ----> 1 T.append(12)
#
# AttributeError: 'tuple' object has no attribute 'append'
