# %% [markdown]
# #初めてのノートブック
# **コードを書いてみましょう**

# %%
#計算する

2*(3+4)
# Out:
# 14

# %% [markdown]
# # [リンクテキスト](https://)#
#
# #First value: 1

# %%
'''
値を出力する
'''
# Out:
# Ellipsis

# %% [markdown]
# **`sort`の関数を呼び出す**
# 1.  以上のリストを作る
#
#
# '''
# Numbers=[4,3,2,1]
# 2.  `sort()`の関数を使って、リストをソートする。
# '''
# ３. `print`を使って、出力する。

# %%
Numbers=[4,3,2,1]
Numbers.sort()
print(Numbers)
# Out:
# [1, 2, 3, 4]
